# %%
from selfiepredict.helpers import Helper_functions
from selfiepredict.data import load_data
import selfies as sf


sf.set_semantic_constraints("hypervalent")

# %%
test = load_data.Data_Cleaner("../data/USPTO_480k/src-test.txt")

# %%
test.raw_data
# Out:
# ['C1CCOC1.N#Cc1ccsc1N.O=[N+]([O-])c1cc(F)c(F)cc1F.[H-].[Na+]',
#  'CCCCP(CCCC)CCCC.COC(=O)Cc1cn(C)c2cc(O)ccc12.Cc1ccccc1.Cc1nn(-c2ccc(C(F)(F)F)cc2)cc1C(C)CO',
#  'CCOCC.Cl.Cl.ClC(Cl)Cl.NC1CCN(CC2Cn3c(=O)ccc4ncc(F)c2c43)CC1O.O=Cc1cc2c(cn1)OCS2',
#  'C=C(C)C(=O)Cl.CC(C)=C1C(=O)N(c2ccc(O)cc2)C(=O)C1=C(C)c1cc(-c2ccccc2)sc1C.CCN(CC)CC.ClCCl',
#  'O=Cc1cncc(Cl)c1COC1CCCCO1.OCc1c(Cl)cncc1Cl',
#  'COc1ccc(CN(Cc2ccc(OC)cc2)c2nc(C)nc(-c3cc(CN4CCN(S(C)(=O)=O)CC4C)cnc3Nc3cnc(OC)c(F)c3)n2)cc1.O=C(O)C(F)(F)F.O=S(=O)(O)C(F)(F)F',
#  'CCCCC1CO1.Cc1cccc(C)c1.Cl.[Cl-]',
#  'C1CCOC1.Cl.OCCCN1CCCCC1.Oc1ccc(-c2nc(CN3CCCCC3)co2)cc1F.c1ccc(P(c2ccccc2)c2ccccc2)cc1',
#  'CSCCNc1cccc2nc(NCc3ccc(C)o3)ccc12.ClCCl.O=C(OO)c1cccc(Cl)c1',
#  'C1CCOC1.CCOCCCO.Clc1nsnc1-c1cccnc1.O.[H-].[Na+]',
#  'C1CCOC1.CC(C)CCCC(C)C1CCC2C3CC=C4CC(OCCCCCCI)CCC4(C)C3CCC12C.NC(N)=S',
#  'CCN(CC)CC.Cl.ClCCl.NCC(=O)N1CCC(=C2c3ccccc3C=Cc3ccccc32)CC1.O=C(Cl)N1CCCCC1',
#  'CC=CCC1C(=O)c2cc(C)ccc2C1(C)C.CO.ClCCl.O=[O+][O-]',
# ...

# %%
test.data2selfie()

# %%
test.selfie2smile()

# %%
test.smile2selfie()

# %%
test.data2smile()

# %%
test.raw_data
# Out:
# ['C1CCOC1.N#Cc1ccsc1N.O=[N+]([O-])c1cc(F)c(F)cc1F.[H-].[Na+]',
#  'CCCCP(CCCC)CCCC.COC(=O)Cc1cn(C)c2cc(O)ccc12.Cc1ccccc1.Cc1nn(-c2ccc(C(F)(F)F)cc2)cc1C(C)CO',
#  'CCOCC.Cl.Cl.ClC(Cl)Cl.NC1CCN(CC2Cn3c(=O)ccc4ncc(F)c2c43)CC1O.O=Cc1cc2c(cn1)OCS2',
#  'C=C(C)C(=O)Cl.CC(C)=C1C(=O)N(c2ccc(O)cc2)C(=O)C1=C(C)c1cc(-c2ccccc2)sc1C.CCN(CC)CC.ClCCl',
#  'O=Cc1cncc(Cl)c1COC1CCCCO1.OCc1c(Cl)cncc1Cl',
#  'COc1ccc(CN(Cc2ccc(OC)cc2)c2nc(C)nc(-c3cc(CN4CCN(S(C)(=O)=O)CC4C)cnc3Nc3cnc(OC)c(F)c3)n2)cc1.O=C(O)C(F)(F)F.O=S(=O)(O)C(F)(F)F',
#  'CCCCC1CO1.Cc1cccc(C)c1.Cl.[Cl-]',
#  'C1CCOC1.Cl.OCCCN1CCCCC1.Oc1ccc(-c2nc(CN3CCCCC3)co2)cc1F.c1ccc(P(c2ccccc2)c2ccccc2)cc1',
#  'CSCCNc1cccc2nc(NCc3ccc(C)o3)ccc12.ClCCl.O=C(OO)c1cccc(Cl)c1',
#  'C1CCOC1.CCOCCCO.Clc1nsnc1-c1cccnc1.O.[H-].[Na+]',
#  'C1CCOC1.CC(C)CCCC(C)C1CCC2C3CC=C4CC(OCCCCCCI)CCC4(C)C3CCC12C.NC(N)=S',
#  'CCN(CC)CC.Cl.ClCCl.NCC(=O)N1CCC(=C2c3ccccc3C=Cc3ccccc32)CC1.O=C(Cl)N1CCCCC1',
#  'CC=CCC1C(=O)c2cc(C)ccc2C1(C)C.CO.ClCCl.O=[O+][O-]',
# ...

# %%
test.data
# Out:
# ['C 1 C C O C 1 . N # C c 1 c c s c 1 N . O = [N+] ( [O-] ) c 1 c c ( F ) c ( F ) c c 1 F . [H-] . [Na+]',
#  'C C C C P ( C C C C ) C C C C . C O C ( = O ) C c 1 c n ( C ) c 2 c c ( O ) c c c 1 2 . C c 1 c c c c c 1 . C c 1 n n ( - c 2 c c c ( C ( F ) ( F ) F ) c c 2 ) c c 1 C ( C ) C O',
#  'C C O C C . Cl . Cl . Cl C ( Cl ) Cl . N C 1 C C N ( C C 2 C n 3 c ( = O ) c c c 4 n c c ( F ) c 2 c 4 3 ) C C 1 O . O = C c 1 c c 2 c ( c n 1 ) O C S 2',
#  'C = C ( C ) C ( = O ) Cl . C C ( C ) = C 1 C ( = O ) N ( c 2 c c c ( O ) c c 2 ) C ( = O ) C 1 = C ( C ) c 1 c c ( - c 2 c c c c c 2 ) s c 1 C . C C N ( C C ) C C . Cl C Cl',
#  'O = C c 1 c n c c ( Cl ) c 1 C O C 1 C C C C O 1 . O C c 1 c ( Cl ) c n c c 1 Cl',
#  'C O c 1 c c c ( C N ( C c 2 c c c ( O C ) c c 2 ) c 2 n c ( C ) n c ( - c 3 c c ( C N 4 C C N ( S ( C ) ( = O ) = O ) C C 4 C ) c n c 3 N c 3 c n c ( O C ) c ( F ) c 3 ) n 2 ) c c 1 . O = C ( O ) C ( F ) ( F ) F . O = S ( = O ) ( O ) C ( F ) ( F ) F',
# ...
