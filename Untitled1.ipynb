# %%
import selfies as sf
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
IPythonConsole.ipython_useSVG=True

# %%
from rdkit.Chem import CanonSmiles

# %%
paper_smiles = "CNC(C)CC1=CC=C2C(=C1)OCO2"

# %%
mol = Chem.MolFromSmiles(paper_smiles)

# %%
Chem.MolFromSmiles("C 1 2 C 3 C 4 C 5 C 1 [Fe] 2 3 4 5 1 6 7 8 C 2 C 1 C 6 C 7 C 2 8 . C S ( C ) = O . C n 1 c ( = O ) c 2 c ( n c n 2 C ) n ( C ) c 1 = O . F C ( F ) ( F ) I . O = S ( = O ) ( O ) O . O = S ( = O ) ( [O-] ) [O-] . O O . [Fe+2]".replace(" ", ""))

# %%
def return_canonical_deb(smiles):
    return Chem.MolToSmiles(Chem.MolFromSmiles(smiles))

# %%
#better use Chem.c
#one canonical is not alway another canonical: https://github.com/rdkit/rdkit/issues/2747

def return_canonical(smiles):
    m = Chem.MolFromSmiles(smiles)
    m.UpdatePropertyCache(strict=False)
    Chem.SanitizeMol(m,Chem.SanitizeFlags.SANITIZE_FINDRADICALS|Chem.SanitizeFlags.SANITIZE_KEKULIZE|Chem.SanitizeFlags.SANITIZE_SETAROMATICITY|Chem.SanitizeFlags.SANITIZE_SETCONJUGATION|Chem.SanitizeFlags.SANITIZE_SETHYBRIDIZATION|Chem.SanitizeFlags.SANITIZE_SYMMRINGS,catchErrors=True)
    return Chem.MolToSmiles(Chem.MolFromSmiles(smiles))

# %%
fail_smiles = "C 1 2 C 3 C 4 C 5 C 1 [Fe] 2 3 4 5 1 6 7 8 C 2 C 1 C 6 C 7 C 2 8 . C S ( C ) = O . C n 1 c ( = O ) c 2 c ( n c n 2 C ) n ( C ) c 1 = O . F C ( F ) ( F ) I . O = S ( = O ) ( O ) O . O = S ( = O ) ( [O-] ) [O-] . O O . [Fe+2]".replace(" ", "")

# %%
CanonSmiles(fail_smiles) == return_canonical_deb(fail_smiles)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5f72c4604f48> in <module>
# ----> 1 CanonSmiles(fail_smiles) == return_canonical_deb(fail_smiles)
#
# NameError: name 'return_canonical_deb' is not defined

# %%
another = "C C C C P ( C C C C ) C C C C . C O C ( = O ) C c 1 c n ( C ) c 2 c c ( O ) c c c 1 2 . C c 1 c c c c c 1 . C c 1 n n ( - c 2 c c c ( C ( F ) ( F ) F ) c c 2 ) c c 1 C ( C ) C O".replace(" ","")

# %%
CanonSmiles(another) == another
# Out:
# True

# %%
CanonSmiles('CNC(C)Cc1ccc2c(c1)OCO2') == return_canonical(paper_smiles)
# Out:
# True

# %%
return_canonical(paper_smiles)
# Out:
# 'CNC(C)Cc1ccc2c(c1)OCO2'

# %%
import selfies as sf

hypervalent_sf = sf.encoder(fail_smiles, strict=False)  # orthoperiodic acid
standard_derived_smi = sf.decoder(hypervalent_sf)
# OI (the default constraints for I allows for only 1 bond)

sf.set_semantic_constraints("hypervalent")
relaxed_derived_smi = sf.decoder(hypervalent_sf)

# %%
sf.decoder(sf.encoder(relaxed_derived_smi)) == standard_derived_smi
# Out:
# True

# %%
standard_derived_smi == relaxed_derived_smi
# Out:
# True

# %%
relaxed_derived_smi
# Out:
# 'CC(C)(O)C1CCNCC1.CCN(C(C)C)C(C)C.CN(C)C(ON2N=NC3=CC=CN=C32)=[N+1](C)C.ClCCl.CN4C(C(=O)O)=NC5=C(N6CCOCC6)N=C(N7C(C8CC8)=NC9=CC=CC=C97)N=C54.F[P-1](F)(F)CF'

# %%
sf.encoder(return_canonical(paper_smiles))
# Out:
# '[C][N][C][Branch1][C][C][C][C][=C][C][=C][C][=Branch1][Ring2][=C][Ring1][=Branch1][O][C][O][Ring1][=Branch1]'

# %%
sf.encoder(paper_smiles)
# Out:
# '[C][N][C][Branch1][C][C][C][C][=C][C][=C][C][=Branch1][Ring2][=C][Ring1][=Branch1][O][C][O][Ring1][=Branch1]'

# %% [markdown]
# Both canonical and non-canonical smiles yield the same SELFIE

# %%
sf.decoder(sf.encoder(paper_smiles))
# Out:
# 'CNC(C)CC1=CC=C2C(=C1)OCO2'

# %%
return_canonical(sf.decoder(sf.encoder(return_canonical(paper_smiles)))) #this should be canonical
# Out:
# 'CNC(C)Cc1ccc2c(c1)OCO2'

# %%
from selfiespredict import data

# %%
cleaner = data.Data_Cleaner(DATAPATH="../data/USPTO_480K/src-test.txt")

# %%
cleaner.raw_data
# Out:
# ['C1CCOC1.N#Cc1ccsc1N.O=[N+]([O-])c1cc(F)c(F)cc1F.[H-].[Na+]',
#  'CCCCP(CCCC)CCCC.COC(=O)Cc1cn(C)c2cc(O)ccc12.Cc1ccccc1.Cc1nn(-c2ccc(C(F)(F)F)cc2)cc1C(C)CO',
#  'CCOCC.Cl.Cl.ClC(Cl)Cl.NC1CCN(CC2Cn3c(=O)ccc4ncc(F)c2c43)CC1O.O=Cc1cc2c(cn1)OCS2',
#  'C=C(C)C(=O)Cl.CC(C)=C1C(=O)N(c2ccc(O)cc2)C(=O)C1=C(C)c1cc(-c2ccccc2)sc1C.CCN(CC)CC.ClCCl',
#  'O=Cc1cncc(Cl)c1COC1CCCCO1.OCc1c(Cl)cncc1Cl',
#  'COc1ccc(CN(Cc2ccc(OC)cc2)c2nc(C)nc(-c3cc(CN4CCN(S(C)(=O)=O)CC4C)cnc3Nc3cnc(OC)c(F)c3)n2)cc1.O=C(O)C(F)(F)F.O=S(=O)(O)C(F)(F)F',
#  'CCCCC1CO1.Cc1cccc(C)c1.Cl.[Cl-]',
#  'C1CCOC1.Cl.OCCCN1CCCCC1.Oc1ccc(-c2nc(CN3CCCCC3)co2)cc1F.c1ccc(P(c2ccccc2)c2ccccc2)cc1',
#  'CSCCNc1cccc2nc(NCc3ccc(C)o3)ccc12.ClCCl.O=C(OO)c1cccc(Cl)c1',
#  'C1CCOC1.CCOCCCO.Clc1nsnc1-c1cccnc1.O.[H-].[Na+]',
#  'C1CCOC1.CC(C)CCCC(C)C1CCC2C3CC=C4CC(OCCCCCCI)CCC4(C)C3CCC12C.NC(N)=S',
#  'CCN(CC)CC.Cl.ClCCl.NCC(=O)N1CCC(=C2c3ccccc3C=Cc3ccccc32)CC1.O=C(Cl)N1CCCCC1',
#  'CC=CCC1C(=O)c2cc(C)ccc2C1(C)C.CO.ClCCl.O=[O+][O-]',
# ...

# %%
# %config Completer.use_jedi = False

# %%
type(cleaner)
# Out:
# selfiespredict.data.load_data.Data_Cleaner

# %%
cleaner._load_data("../data/USPTO_480K/src-test.txt")

# %%
from selfiespredict.helpers.Helper_functions import smi_tokenizer

# %%
smi_tokenizer(fail_smiles) == "C C ( C ) ( O ) C 1 C C N C C 1 . C C N ( C ( C ) C ) C ( C ) C . C N ( C ) C ( O n 1 n n c 2 c c c n c 2 1 ) = [N+] ( C ) C . Cl C Cl . C n 1 c ( C ( = O ) O ) n c 2 c ( N 3 C C O C C 3 ) n c ( - n 3 c ( C 4 C C 4 ) n c 4 c c c c c 4 3 ) n c 2 1 . F [P-] ( F ) ( F ) ( F ) ( F ) F"
# Out:
# True

# %%
#sf.set_semantic_constraints("hypervalent")
CanonSmiles(sf.decoder(sf.encoder(fail_smiles,strict=False))) == fail_smiles
# Out:
# False

# %%
fail_smiles
# Out:
# 'CC(C)(O)C1CCNCC1.CCN(C(C)C)C(C)C.CN(C)C(On1nnc2cccnc21)=[N+](C)C.ClCCl.Cn1c(C(=O)O)nc2c(N3CCOCC3)nc(-n3c(C4CC4)nc4ccccc43)nc21.F[P-](F)(F)(F)(F)F'

# %%
hypervalent_sf = sf.encoder(fail_smiles, strict=False) 
standard_derived_smi = sf.decoder(hypervalent_sf)

sf.set_semantic_constraints("hypervalent")
sf.decoder(hypervalent_sf)
#returns 'CC(C)(O)C1CCNCC1.CCN(C(C)C)C(C)C.CN(C)C(ON2N=NC3=CC=CN=C32)=[N+1](C)C.ClCCl.CN4C(C(=O)O)=NC5=C(N6CCOCC6)N=C(N7C(C8CC8)=NC9=CC=CC=C97)N=C54.F[P-1](F)(F)CF'
# Out:
# 'C12C3C4C5C1[Fe]234567C8C6C7CC8.CS(C)=O.CN9C(=O)C%10=C(N=CN%10C)N(C)C9=O.FC(F)(F)I.O=S(=O)(O)O.O=S(=O)([O-1])[O-1].OO.[Fe+2]'

# %%
Chem.MolFromSmiles("C12C3C4C5C1[Fe]234567C8C6C7CC8.CS(C)=O.CN9C(=O)C%10=C(N=CN%10C)N(C)C9=O.FC(F)(F)I.O=S(=O)(O)O.O=S(=O)([O-1])[O-1].OO.[Fe+2]")

# %%
sf.decoder(hypervalent_sf)
# Out:
# 'F[P-1](F)(F)CF'

# %%
sf.set_semantic_constraints("hypervalent")
sf.encoder(fail_smiles,strict=False)
# Out:
# '[F][P-1][Branch1][C][F][Branch1][C][F][Branch1][C][F][Branch1][C][F][F]'

# %%
"[P-]" in fail_smiles  #add exception
# Out:
# True

# %%
Chem.MolFromSmiles("F[P-1](F)(F)CF")

# %%
Chem.MolFromSmiles("F[P-](F)(F)(F)(F)F")

# %%
CanonSmiles(fail_smiles) == fail_smiles
# Out:
# True

# %%
import unittest

# %%
assertTrue(all([repr1 == conversion(repr1) for repr1 in data]))
